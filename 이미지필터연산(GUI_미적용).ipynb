# %% [markdown]
# <a href="https://colab.research.google.com/github/ziuom/ziuom/blob/main/%EC%9D%B4%EB%AF%B8%EC%A7%80%ED%95%84%ED%84%B0%EC%97%B0%EC%82%B0(GUI_%EB%AF%B8%EC%A0%81%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# !pip install kaggle

# %%
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-0c9e8ea4-ca40-4118-9550-630650b00b49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c9e8ea4-ca40-4118-9550-630650b00b49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d hemendrasr/pizza-vs-ice-cream
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hemendrasr/pizza-vs-ice-cream
# License(s): other
# ...
#  79% 33.0M/41.7M [00:00<00:00, 81.4MB/s]
# 100% 41.7M/41.7M [00:00<00:00, 81.4MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/pizza-vs-ice-cream.zip', 'r') as zip_ref:
    zip_ref.extractall('pizza_cream')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#예제 이미지 경로 설정
image_path = '/content/pizza_cream/dataset/test/pizza/00520_jpg.rf.bf3ec46ff32ef4d4a28148683cac5f38.jpg'

#이미지 로드
image = cv2.imread(image_path)

#이미지가 정상적으로 로드되었는지 확인
if image is None:
    print("이미지를 찾을 수 없습니다.")
    exit()

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

blurred_image = cv2.GaussianBlur(image_rgb, (15, 15), 0)

edges_image = cv2.Canny(image_rgb, 100, 200)

plt.figure(figsize=(10, 10))

# %%
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(image_rgb)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Blurred Image')
plt.imshow(blurred_image)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Edges Image')
plt.imshow(edges_image, cmap='gray')
plt.axis('off')

plt.show()
